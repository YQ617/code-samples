# %% [markdown]
# <a href="https://colab.research.google.com/github/YQ617/code-samples/blob/main/Final_Project_Yanfei_Qin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Project
# ### Name: Yanfei Qin
# ### PennKey: yfqin
# ### PennID: 51386260

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-769b5609-c91f-4d04-9aa4-c005a6f9a933" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-769b5609-c91f-4d04-9aa4-c005a6f9a933">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving UNIDO_IIP.xlsx to UNIDO_IIP.xlsx

# %%
import pandas as pd
UNIDO_IIP = pd.read_excel('UNIDO_IIP.xlsx', sheet_name = 'Layout')
UNIDO_IIP
# Out:
#       Country Code Country Description  Table Code  ... 2021 M06 2021 M07 2021 M08
# 0               32           Argentina          51  ...    102.5    101.4      ...
# 1               32           Argentina          51  ...    102.5    101.4      ...
# 2               32           Argentina          51  ...      ...      ...      ...
# 3               32           Argentina          51  ...     78.6     79.2      ...
# 4               32           Argentina          51  ...      ...      ...      ...
# ...            ...                 ...         ...  ...      ...      ...      ...
# 4475           704            Viet Nam          52  ...      ...      ...      ...
# 4476           704            Viet Nam          52  ...     82.8     81.5      ...
# 4477           704            Viet Nam          52  ...    151.3    151.7      ...
# 4478           704            Viet Nam          52  ...    189.8    183.5      ...
# ...

# %% [markdown]
# # Sub-Task 1: Cleaning Dataset and Constructing DataFrames

# %% [markdown]
# ## Cleaning Dataset

# %%
UNIDO_IIP_cleaning = UNIDO_IIP.drop(UNIDO_IIP.columns[[0,2,7]], axis=1) 
UNIDO_IIP_cleaning
# Out:
#      Country Description                    Table Description  ... 2021 M07 2021 M08
# 0              Argentina  Seasonally adjusted index(2015=100)  ...    101.4      ...
# 1              Argentina  Seasonally adjusted index(2015=100)  ...    101.4      ...
# 2              Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# 3              Argentina  Seasonally adjusted index(2015=100)  ...     79.2      ...
# 4              Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# ...                  ...                                  ...  ...      ...      ...
# 4475            Viet Nam             Original index(2015=100)  ...      ...      ...
# 4476            Viet Nam             Original index(2015=100)  ...     81.5      ...
# 4477            Viet Nam             Original index(2015=100)  ...    151.7      ...
# 4478            Viet Nam             Original index(2015=100)  ...    183.5      ...
# ...

# %%
UNIDO_IIP_cleaning = UNIDO_IIP_cleaning.drop(UNIDO_IIP_cleaning.iloc[:, 5:49], axis = 1)
UNIDO_IIP_cleaning
# Out:
#      Country Description                    Table Description  ... 2021 M07 2021 M08
# 0              Argentina  Seasonally adjusted index(2015=100)  ...    101.4      ...
# 1              Argentina  Seasonally adjusted index(2015=100)  ...    101.4      ...
# 2              Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# 3              Argentina  Seasonally adjusted index(2015=100)  ...     79.2      ...
# 4              Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# ...                  ...                                  ...  ...      ...      ...
# 4475            Viet Nam             Original index(2015=100)  ...      ...      ...
# 4476            Viet Nam             Original index(2015=100)  ...     81.5      ...
# 4477            Viet Nam             Original index(2015=100)  ...    151.7      ...
# 4478            Viet Nam             Original index(2015=100)  ...    183.5      ...
# ...

# %%
UNIDO_IIP_cleaning = UNIDO_IIP_cleaning.drop(UNIDO_IIP_cleaning.iloc[:, 22:143], axis = 1)
UNIDO_IIP_cleaning
# Out:
#      Country Description                    Table Description  ... 2021 M07 2021 M08
# 0              Argentina  Seasonally adjusted index(2015=100)  ...    101.4      ...
# 1              Argentina  Seasonally adjusted index(2015=100)  ...    101.4      ...
# 2              Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# 3              Argentina  Seasonally adjusted index(2015=100)  ...     79.2      ...
# 4              Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# ...                  ...                                  ...  ...      ...      ...
# 4475            Viet Nam             Original index(2015=100)  ...      ...      ...
# 4476            Viet Nam             Original index(2015=100)  ...     81.5      ...
# 4477            Viet Nam             Original index(2015=100)  ...    151.7      ...
# 4478            Viet Nam             Original index(2015=100)  ...    183.5      ...
# ...

# %%
UNIDO_IIP_cleaning2 = UNIDO_IIP_cleaning.drop(UNIDO_IIP_cleaning.columns[[39]], axis=1) 
UNIDO_IIP_cleaning2.head()
# Out:
#   Country Description                    Table Description  ... 2021 M06 2021 M07
# 0           Argentina  Seasonally adjusted index(2015=100)  ...    102.5    101.4
# 1           Argentina  Seasonally adjusted index(2015=100)  ...    102.5    101.4
# 2           Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# 3           Argentina  Seasonally adjusted index(2015=100)  ...     78.6     79.2
# 4           Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
#
# [5 rows x 39 columns]

# %%
UNIDO_IIP_cleaning2 = UNIDO_IIP_cleaning2.rename(columns={'Country Description':'Country_Description'})
UNIDO_IIP_cleaning2 = UNIDO_IIP_cleaning2.rename(columns={'Table Description':'Table_Description'})
UNIDO_IIP_cleaning2 = UNIDO_IIP_cleaning2.rename(columns={'ISIC Description':'ISIC_Description'})
UNIDO_IIP_cleaning2.head()
# Out:
#   Country_Description                    Table_Description  ... 2021 M06 2021 M07
# 0           Argentina  Seasonally adjusted index(2015=100)  ...    102.5    101.4
# 1           Argentina  Seasonally adjusted index(2015=100)  ...    102.5    101.4
# 2           Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
# 3           Argentina  Seasonally adjusted index(2015=100)  ...     78.6     79.2
# 4           Argentina  Seasonally adjusted index(2015=100)  ...      ...      ...
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Constructing Five Countries' Individual Dataframes and a Combined Five Countries' Total Manufacturing Dataframes

# %%
US_IIP = UNIDO_IIP_cleaning2.query("Country_Description.str.contains('United States of America')",engine='python')
US_IIP_SAI = US_IIP.query("Table_Description.str.contains('Seasonally adjusted index')",engine='python')
US_IIP_SAI = US_IIP_SAI.reset_index()
US_IIP_SAI = US_IIP_SAI.drop(US_IIP_SAI.columns[[0,2,3,5]], axis=1) 
US_IIP_SAI['ISIC_Description'] = US_IIP_SAI['ISIC_Description'].replace(r'\d ', '', regex=True)
US_IIP_SAI['ISIC_Description'] = US_IIP_SAI['ISIC_Description'].replace(r'\d', '', regex=True)
US_IIP_SAI['ISIC_Description'] = US_IIP_SAI['ISIC_Description'].replace(r'C Total manufacturing', 'Total manufacturing', regex=True)
US_IIP_SAI
# Out:
#          Country_Description  ... 2021 M07
# 0   United States of America  ...      102
# 1   United States of America  ...    103.4
# 2   United States of America  ...     87.2
# 3   United States of America  ...     85.3
# 4   United States of America  ...     88.8
# 5   United States of America  ...    106.2
# 6   United States of America  ...    104.7
# 7   United States of America  ...     92.9
# 8   United States of America  ...     93.8
# 9   United States of America  ...      106
# 10  United States of America  ...     98.1
# 11  United States of America  ...    101.9
# 12  United States of America  ...     98.4
# 13  United States of America  ...     96.3
# 14  United States of America  ...     94.1
# 15  United States of America  ...     94.8
# 16  United States of America  ...    133.4
# 17  United States of America  ...    103.5
# 18  United States of America  ...    103.4
# 19  United States of America  ...       96
# 20  United States of America  ...     94.5
# ...

# %%
CN_IIP = UNIDO_IIP_cleaning2.query("Country_Description.str.contains('China')",engine='python')
CN_IIP_SAI = CN_IIP.query("Table_Description.str.contains('Seasonally adjusted index')",engine='python')
CN_IIP_SAI = CN_IIP_SAI.reset_index()
CN_IIP_SAI = CN_IIP_SAI.drop(CN_IIP_SAI.columns[[0,2,3,5]], axis=1) 
CN_IIP_SAI['ISIC_Description'] = CN_IIP_SAI['ISIC_Description'].replace(r'\d ', '', regex=True)
CN_IIP_SAI['ISIC_Description'] = CN_IIP_SAI['ISIC_Description'].replace(r'\d', '', regex=True)
CN_IIP_SAI['ISIC_Description'] = CN_IIP_SAI['ISIC_Description'].replace(r'C Total manufacturing', 'Total manufacturing', regex=True)
CN_IIP_SAI #It appears we need to deal with data from Taiwan
# Out:
#        Country_Description  ... 2021 M07
# 0                    China  ...    132.7
# 1                    China  ...    141.6
# 2                    China  ...    110.9
# 3                    China  ...    113.3
# 4                    China  ...    114.2
# 5                    China  ...    109.7
# 6                    China  ...    126.3
# 7                    China  ...    125.5
# 8                    China  ...      138
# 9                    China  ...    128.5
# 10                   China  ...    138.5
# 11                   China  ...    193.6
# 12                   China  ...    133.3
# 13                   China  ...    142.4
# 14                   China  ...    128.8
# 15                   China  ...    155.1
# 16                   China  ...    194.2
# 17                   China  ...    180.1
# 18                   China  ...    160.6
# 19                   China  ...    142.8
# 20                   China  ...    128.9
# 21                   China  ...    136.2
# ...

# %%
CN_IIP_SAI = CN_IIP_SAI.query("~Country_Description.str.contains('Taiwan')",engine='python')
CN_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0                China  ...    132.7
# 1                China  ...    141.6
# 2                China  ...    110.9
# 3                China  ...    113.3
# 4                China  ...    114.2
# 5                China  ...    109.7
# 6                China  ...    126.3
# 7                China  ...    125.5
# 8                China  ...      138
# 9                China  ...    128.5
# 10               China  ...    138.5
# 11               China  ...    193.6
# 12               China  ...    133.3
# 13               China  ...    142.4
# 14               China  ...    128.8
# 15               China  ...    155.1
# 16               China  ...    194.2
# 17               China  ...    180.1
# 18               China  ...    160.6
# 19               China  ...    142.8
# 20               China  ...    128.9
# 21               China  ...    136.2
# 22               China  ...    128.5
# 23               China  ...      ...
# ...

# %%
JP_IIP = UNIDO_IIP_cleaning2.query("Country_Description.str.contains('Japan')",engine='python')
JP_IIP_SAI = JP_IIP.query("Table_Description.str.contains('Seasonally adjusted index')",engine='python')
JP_IIP_SAI = JP_IIP_SAI.reset_index()
JP_IIP_SAI = JP_IIP_SAI.drop(JP_IIP_SAI.columns[[0,2,3,5]], axis=1) 
JP_IIP_SAI['ISIC_Description'] = JP_IIP_SAI['ISIC_Description'].replace(r'\d ', '', regex=True)
JP_IIP_SAI['ISIC_Description'] = JP_IIP_SAI['ISIC_Description'].replace(r'\d', '', regex=True)
JP_IIP_SAI['ISIC_Description'] = JP_IIP_SAI['ISIC_Description'].replace(r'C Total manufacturing', 'Total manufacturing', regex=True)
JP_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0                Japan  ...     97.5
# 1                Japan  ...     97.5
# 2                Japan  ...     97.5
# 3                Japan  ...     82.7
# 4                Japan  ...     82.7
# 5                Japan  ...     62.9
# 6                Japan  ...    108.6
# 7                Japan  ...     95.1
# 8                Japan  ...     76.9
# 9                Japan  ...     76.2
# 10               Japan  ...    100.4
# 11               Japan  ...    100.4
# 12               Japan  ...    100.4
# 13               Japan  ...     92.5
# 14               Japan  ...     96.3
# 15               Japan  ...     91.1
# 16               Japan  ...    105.8
# 17               Japan  ...    101.8
# 18               Japan  ...    114.9
# 19               Japan  ...     90.7
# 20               Japan  ...     90.7
# 21               Japan  ...     93.1
# 22               Japan  ...    102.4
# 23               Japan  ...      ...
# ...

# %%
DE_IIP = UNIDO_IIP_cleaning2.query("Country_Description.str.contains('Germany')",engine='python')
DE_IIP_SAI = DE_IIP.query("Table_Description.str.contains('Seasonally adjusted index')",engine='python')
DE_IIP_SAI = DE_IIP_SAI.reset_index()
DE_IIP_SAI = DE_IIP_SAI.drop(DE_IIP_SAI.columns[[0,2,3,5]], axis=1) 
DE_IIP_SAI['ISIC_Description'] = DE_IIP_SAI['ISIC_Description'].replace(r'\d ', '', regex=True)
DE_IIP_SAI['ISIC_Description'] = DE_IIP_SAI['ISIC_Description'].replace(r'\d', '', regex=True)
DE_IIP_SAI['ISIC_Description'] = DE_IIP_SAI['ISIC_Description'].replace(r'C Total manufacturing', 'Total manufacturing', regex=True)
DE_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0              Germany  ...    106.8
# 1              Germany  ...    101.7
# 2              Germany  ...     74.1
# 3              Germany  ...       99
# 4              Germany  ...     63.4
# 5              Germany  ...    109.8
# 6              Germany  ...    110.3
# 7              Germany  ...    100.5
# 8              Germany  ...     82.8
# 9              Germany  ...     87.4
# 10             Germany  ...       99
# 11             Germany  ...    120.1
# 12             Germany  ...    101.3
# 13             Germany  ...    102.8
# 14             Germany  ...     87.7
# 15             Germany  ...    102.8
# 16             Germany  ...    120.5
# 17             Germany  ...    105.2
# 18             Germany  ...     98.3
# 19             Germany  ...     64.7
# 20             Germany  ...    116.9
# 21             Germany  ...     96.7
# 22             Germany  ...      109
# 23             Germany  ...    101.6
# ...

# %%
UK_IIP = UNIDO_IIP_cleaning2.query("Country_Description.str.contains('United Kingdom')",engine='python')
UK_IIP_SAI = UK_IIP.query("Table_Description.str.contains('Seasonally adjusted index')",engine='python')
UK_IIP_SAI = UK_IIP_SAI.reset_index()
UK_IIP_SAI = UK_IIP_SAI.drop(UK_IIP_SAI.columns[[0,2,3,5]], axis=1) 
UK_IIP_SAI['ISIC_Description'] = UK_IIP_SAI['ISIC_Description'].replace(r'\d ', '', regex=True)
UK_IIP_SAI['ISIC_Description'] = UK_IIP_SAI['ISIC_Description'].replace(r'\d', '', regex=True)
UK_IIP_SAI['ISIC_Description'] = UK_IIP_SAI['ISIC_Description'].replace(r'C Total manufacturing', 'Total manufacturing', regex=True)
UK_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0       United Kingdom  ...    107.8
# 1       United Kingdom  ...       95
# 2       United Kingdom  ...       95
# 3       United Kingdom  ...    111.6
# 4       United Kingdom  ...       77
# 5       United Kingdom  ...    103.4
# 6       United Kingdom  ...    115.4
# 7       United Kingdom  ...    104.1
# 8       United Kingdom  ...     90.6
# 9       United Kingdom  ...     89.1
# 10      United Kingdom  ...    102.6
# 11      United Kingdom  ...    121.9
# 12      United Kingdom  ...     98.3
# 13      United Kingdom  ...    103.6
# 14      United Kingdom  ...     73.4
# 15      United Kingdom  ...     96.2
# 16      United Kingdom  ...    111.2
# 17      United Kingdom  ...     91.5
# 18      United Kingdom  ...     94.3
# 19      United Kingdom  ...     74.8
# 20      United Kingdom  ...     79.8
# 21      United Kingdom  ...    109.3
# 22      United Kingdom  ...    122.5
# 23      United Kingdom  ...    102.2
# ...

# %%
# Now we keep to keep the Seasonally Adjusted Indices that all five countries have in common with no NaN Data.
# By investigating the data, we need to delete ISIC 33/B/D/E.
US_IIP_SAI = US_IIP_SAI.drop(labels=[23,24,26,27], axis=0)
US_IIP_SAI
# Out:
#          Country_Description  ... 2021 M07
# 0   United States of America  ...      102
# 1   United States of America  ...    103.4
# 2   United States of America  ...     87.2
# 3   United States of America  ...     85.3
# 4   United States of America  ...     88.8
# 5   United States of America  ...    106.2
# 6   United States of America  ...    104.7
# 7   United States of America  ...     92.9
# 8   United States of America  ...     93.8
# 9   United States of America  ...      106
# 10  United States of America  ...     98.1
# 11  United States of America  ...    101.9
# 12  United States of America  ...     98.4
# 13  United States of America  ...     96.3
# 14  United States of America  ...     94.1
# 15  United States of America  ...     94.8
# 16  United States of America  ...    133.4
# 17  United States of America  ...    103.5
# 18  United States of America  ...    103.4
# 19  United States of America  ...       96
# 20  United States of America  ...     94.5
# ...

# %%
CN_IIP_SAI = CN_IIP_SAI.drop(labels=[23,24,26,27], axis=0)
CN_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0                China  ...    132.7
# 1                China  ...    141.6
# 2                China  ...    110.9
# 3                China  ...    113.3
# 4                China  ...    114.2
# 5                China  ...    109.7
# 6                China  ...    126.3
# 7                China  ...    125.5
# 8                China  ...      138
# 9                China  ...    128.5
# 10               China  ...    138.5
# 11               China  ...    193.6
# 12               China  ...    133.3
# 13               China  ...    142.4
# 14               China  ...    128.8
# 15               China  ...    155.1
# 16               China  ...    194.2
# 17               China  ...    180.1
# 18               China  ...    160.6
# 19               China  ...    142.8
# 20               China  ...    128.9
# 21               China  ...    136.2
# 22               China  ...    128.5
# 25               China  ...    148.8
#
# ...

# %%
JP_IIP_SAI = JP_IIP_SAI.drop(labels=[23,24,26,27], axis=0)
JP_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0                Japan  ...     97.5
# 1                Japan  ...     97.5
# 2                Japan  ...     97.5
# 3                Japan  ...     82.7
# 4                Japan  ...     82.7
# 5                Japan  ...     62.9
# 6                Japan  ...    108.6
# 7                Japan  ...     95.1
# 8                Japan  ...     76.9
# 9                Japan  ...     76.2
# 10               Japan  ...    100.4
# 11               Japan  ...    100.4
# 12               Japan  ...    100.4
# 13               Japan  ...     92.5
# 14               Japan  ...     96.3
# 15               Japan  ...     91.1
# 16               Japan  ...    105.8
# 17               Japan  ...    101.8
# 18               Japan  ...    114.9
# 19               Japan  ...     90.7
# 20               Japan  ...     90.7
# 21               Japan  ...     93.1
# 22               Japan  ...    102.4
# 25               Japan  ...     98.1
#
# ...

# %%
DE_IIP_SAI = DE_IIP_SAI.drop(labels=[23,24,26,27], axis=0)
DE_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0              Germany  ...    106.8
# 1              Germany  ...    101.7
# 2              Germany  ...     74.1
# 3              Germany  ...       99
# 4              Germany  ...     63.4
# 5              Germany  ...    109.8
# 6              Germany  ...    110.3
# 7              Germany  ...    100.5
# 8              Germany  ...     82.8
# 9              Germany  ...     87.4
# 10             Germany  ...       99
# 11             Germany  ...    120.1
# 12             Germany  ...    101.3
# 13             Germany  ...    102.8
# 14             Germany  ...     87.7
# 15             Germany  ...    102.8
# 16             Germany  ...    120.5
# 17             Germany  ...    105.2
# 18             Germany  ...     98.3
# 19             Germany  ...     64.7
# 20             Germany  ...    116.9
# 21             Germany  ...     96.7
# 22             Germany  ...      109
# 25             Germany  ...       96
#
# ...

# %%
UK_IIP_SAI = UK_IIP_SAI.drop(labels=[23,24,26,27], axis=0)
UK_IIP_SAI
# Out:
#    Country_Description  ... 2021 M07
# 0       United Kingdom  ...    107.8
# 1       United Kingdom  ...       95
# 2       United Kingdom  ...       95
# 3       United Kingdom  ...    111.6
# 4       United Kingdom  ...       77
# 5       United Kingdom  ...    103.4
# 6       United Kingdom  ...    115.4
# 7       United Kingdom  ...    104.1
# 8       United Kingdom  ...     90.6
# 9       United Kingdom  ...     89.1
# 10      United Kingdom  ...    102.6
# 11      United Kingdom  ...    121.9
# 12      United Kingdom  ...     98.3
# 13      United Kingdom  ...    103.6
# 14      United Kingdom  ...     73.4
# 15      United Kingdom  ...     96.2
# 16      United Kingdom  ...    111.2
# 17      United Kingdom  ...     91.5
# 18      United Kingdom  ...     94.3
# 19      United Kingdom  ...     74.8
# 20      United Kingdom  ...     79.8
# 21      United Kingdom  ...    109.3
# 22      United Kingdom  ...    122.5
# 25      United Kingdom  ...     98.7
#
# ...

# %%
Five_IIP_SAI = pd.concat([US_IIP_SAI,CN_IIP_SAI, JP_IIP_SAI, DE_IIP_SAI, UK_IIP_SAI])
Five_IIP_SAI
# Out:
#          Country_Description  ... 2021 M07
# 0   United States of America  ...      102
# 1   United States of America  ...    103.4
# 2   United States of America  ...     87.2
# 3   United States of America  ...     85.3
# 4   United States of America  ...     88.8
# ..                       ...  ...      ...
# 19            United Kingdom  ...     74.8
# 20            United Kingdom  ...     79.8
# 21            United Kingdom  ...    109.3
# 22            United Kingdom  ...    122.5
# 25            United Kingdom  ...     98.7
#
# [120 rows x 36 columns]

# %%
Five_IIP_SAI = Five_IIP_SAI.query("ISIC_Description.str.contains('Total manufacturing')",engine='python')
Five_IIP_SAI
# Out:
#          Country_Description     ISIC_Description  ... 2021 M06 2021 M07
# 25  United States of America  Total manufacturing  ...     98.7    100.3
# 25                     China  Total manufacturing  ...      149    148.8
# 25                     Japan  Total manufacturing  ...     99.7     98.1
# 25                   Germany  Total manufacturing  ...     94.8       96
# 25            United Kingdom  Total manufacturing  ...     98.7     98.7
#
# [5 rows x 36 columns]

# %%
Tot_M_IIP = Five_IIP_SAI.drop(Five_IIP_SAI.columns[1], axis=1) 
Tot_M_IIP = Tot_M_IIP.set_index('Country_Description')
Tot_M_IIP
#this dataframe will be used Total Manufacturing as the indicator to compare the trends between five countries
# Out:
#                          2008 M09 2008 M10 2008 M11  ... 2021 M05 2021 M06 2021 M07
# Country_Description                                  ...
# United States of America     96.7     96.2     93.8  ...     98.9     98.7    100.3
# China                        47.6     47.7     46.9  ...    148.1      149    148.8
# Japan                       111.9    109.3    101.9  ...     93.5     99.7     98.1
# Germany                      97.5     95.5     91.5  ...     95.5     94.8       96
# United Kingdom              100.8    100.6     97.5  ...     98.5     98.7     98.7
#
# [5 rows x 34 columns]

# %%
Tot_M_IIP.to_csv('Total Manufacturing IIPs.csv')

# %%
US_IIP_SAI= US_IIP_SAI.drop(US_IIP_SAI.columns[0], axis=1) 
US_IIP_SAI = US_IIP_SAI.set_index('ISIC_Description')
US_IIP_SAI
# Out:
#                                             2008 M09 2008 M10  ... 2021 M06 2021 M07
# ISIC_Description                                               ...
# Food products                                   95.6     96.9  ...    102.7      102
# Beverages                                       82.7     81.3  ...    102.3    103.4
# Tobacco products                               127.4    124.1  ...     87.2     87.2
# Textiles                                       120.3    117.2  ...     84.8     85.3
# Wearing apparel                                178.3    171.4  ...     88.5     88.8
# Leather and related products                   135.9    128.5  ...    106.7    106.2
# Wood products, excluding furniture             102.5     97.1  ...    103.6    104.7
# Paper and paper products                       106.9    103.4  ...     92.1     92.9
# Printing and reproduction of recorded media      125    123.7  ...     93.5     93.8
# ...

# %%
US_IIP_SAI = US_IIP_SAI.drop(labels=['Total manufacturing'], axis=0) 
#we decide not to include total manufacturing in the analysis of individual countries, since it will complicated the visualization as it is putted together with specific industries

# %%
US_IIP_SAI.to_csv('US_IIP_SAI.csv')

# %%
CN_IIP_SAI= CN_IIP_SAI.drop(CN_IIP_SAI.columns[0], axis=1) 
CN_IIP_SAI = CN_IIP_SAI.set_index('ISIC_Description')
CN_IIP_SAI
# Out:
#                                             2008 M09 2008 M10  ... 2021 M06 2021 M07
# ISIC_Description                                               ...
# Food products                                   47.4     48.3  ...    133.3    132.7
# Beverages                                         46       47  ...    139.6    141.6
# Tobacco products                                58.2     60.4  ...    108.3    110.9
# Textiles                                        56.1     56.1  ...    113.7    113.3
# Wearing apparel                                   55     54.6  ...    113.8    114.2
# Leather and related products                    54.8     54.3  ...    109.7    109.7
# Wood products, excluding furniture              40.7     41.5  ...    128.4    126.3
# Paper and paper products                        53.3     52.9  ...    126.2    125.5
# Printing and reproduction of recorded media     50.4     50.5  ...    138.6      138
# ...

# %%
CN_IIP_SAI = CN_IIP_SAI.drop(labels=['Total manufacturing'], axis=0)

# %%
CN_IIP_SAI.to_csv('CN_IIP_SAI.csv')

# %%
JP_IIP_SAI= JP_IIP_SAI.drop(JP_IIP_SAI.columns[0], axis=1) 
JP_IIP_SAI = JP_IIP_SAI.set_index('ISIC_Description')
JP_IIP_SAI = JP_IIP_SAI.drop(labels=['Total manufacturing'], axis=0) 
JP_IIP_SAI
# Out:
#                                             2008 M09 2008 M10  ... 2021 M06 2021 M07
# ISIC_Description                                               ...
# Food products                                  102.3    104.8  ...     96.4     97.5
# Beverages                                      102.3    104.8  ...     96.4     97.5
# Tobacco products                               102.3    104.8  ...     96.4     97.5
# Textiles                                         119      119  ...       81     82.7
# Wearing apparel                                  119      119  ...       81     82.7
# Leather and related products                   159.8    154.8  ...     60.8     62.9
# Wood products, excluding furniture             118.5    118.3  ...    105.4    108.6
# Paper and paper products                       110.8    105.4  ...     90.3     95.1
# Printing and reproduction of recorded media    107.7    107.2  ...     77.6     76.9
# ...

# %%
JP_IIP_SAI.to_csv('JP_IIP_SAI.csv')

# %%
DE_IIP_SAI= DE_IIP_SAI.drop(DE_IIP_SAI.columns[0], axis=1) 
DE_IIP_SAI = DE_IIP_SAI.set_index('ISIC_Description')
DE_IIP_SAI = DE_IIP_SAI.drop(labels=['Total manufacturing'], axis=0)

# %%
DE_IIP_SAI.to_csv('DE_IIP_SAI.csv')

# %%
UK_IIP_SAI= UK_IIP_SAI.drop(UK_IIP_SAI.columns[0], axis=1) 
UK_IIP_SAI = UK_IIP_SAI.set_index('ISIC_Description')
UK_IIP_SAI = UK_IIP_SAI.drop(labels=['Total manufacturing'], axis=0) 
UK_IIP_SAI
# Out:
#                                             2008 M09 2008 M10  ... 2021 M06 2021 M07
# ISIC_Description                                               ...
# Food products                                   92.4     93.4  ...    107.8    107.8
# Beverages                                       90.7     95.3  ...     96.1       95
# Tobacco products                                90.7     95.3  ...     96.1       95
# Textiles                                       136.3    131.8  ...    112.5    111.6
# Wearing apparel                                104.2      105  ...     79.7       77
# Leather and related products                    92.8     86.9  ...    106.1    103.4
# Wood products, excluding furniture               119    118.6  ...    115.4    115.4
# Paper and paper products                       106.7    103.8  ...    100.8    104.1
# Printing and reproduction of recorded media    119.8    110.4  ...       87     90.6
# ...

# %%
UK_IIP_SAI.to_csv('UK_IIP_SAI.csv') #in total of 5 individual dataframes have been produced to analyze and visualize the trend in one specific country's various industries.

# %%
July_2021 = pd.DataFrame(pd.concat([US_IIP_SAI['2021 M07'],CN_IIP_SAI['2021 M07'],JP_IIP_SAI['2021 M07'],DE_IIP_SAI['2021 M07'],UK_IIP_SAI['2021 M07']], axis=1))
July_2021 =July_2021.set_axis(['USA', 'China', 'Japan', 'Germany', 'UK'], axis='columns')
July_2021 = July_2021.reset_index()
July_2021 = July_2021.rename(columns={'ISIC_Description':'Industry_Sector'})
July_2021
# Out:
#                                 Industry_Sector    USA  ... Germany     UK
# 0                                 Food products    102  ...   106.8  107.8
# 1                                     Beverages  103.4  ...   101.7     95
# 2                              Tobacco products   87.2  ...    74.1     95
# 3                                      Textiles   85.3  ...      99  111.6
# 4                               Wearing apparel   88.8  ...    63.4     77
# 5                  Leather and related products  106.2  ...   109.8  103.4
# 6            Wood products, excluding furniture  104.7  ...   110.3  115.4
# 7                      Paper and paper products   92.9  ...   100.5  104.1
# 8   Printing and reproduction of recorded media   93.8  ...    82.8   90.6
# 9           Coke and refined petroleum products    106  ...    87.4   89.1
# 10              Chemicals and chemical products   98.1  ...      99  102.6
# ...

# %% [markdown]
# ## Transfer 20xx Mxx format to datetime format

# %%
Tot_M_IIP2 = Tot_M_IIP
Tot_M_IIP2.index.names = ['']
Tot_M_IIP2 =Tot_M_IIP2.T
Tot_M_IIP2 = Tot_M_IIP2.reset_index()
Tot_M_IIP2['index'] = Tot_M_IIP2['index'].replace(r' M', '-', regex=True)
Tot_M_IIP2 = Tot_M_IIP2.rename(columns={'index':'Year-Month'})
Tot_M_IIP2
# Out:
#    Year-Month United States of America  China  Japan Germany United Kingdom
# 0     2008-09                     96.7   47.6  111.9    97.5          100.8
# 1     2008-10                     96.2   47.7  109.3    95.5          100.6
# 2     2008-11                     93.8   46.9  101.9    91.5           97.5
# 3     2008-12                     90.5   47.6   93.4    87.8           95.9
# 4     2009-01                     87.6   48.7   85.2    80.6           93.2
# 5     2009-02                     87.6     51   77.9      78           92.9
# 6     2009-03                     86.1   49.8   78.9    78.5             93
# 7     2009-04                     85.5   50.4   82.3    76.4           94.8
# 8     2009-05                     84.6   51.2   85.5    79.9           92.6
# 9     2009-06                     84.4   52.1   87.1    80.7           92.6
# 10    2009-07                     85.8   52.7   88.2    79.8           92.9
# ...

# %%
Tot_M_IIP2['Year-Month'] = pd.to_datetime(Tot_M_IIP2['Year-Month'], format='%Y-%m').dt.strftime('%Y-%m')
Tot_M_IIP2.head()
# Out:
#   Year-Month United States of America China  Japan Germany United Kingdom
# 0    2008-09                     96.7  47.6  111.9    97.5          100.8
# 1    2008-10                     96.2  47.7  109.3    95.5          100.6
# 2    2008-11                     93.8  46.9  101.9    91.5           97.5
# 3    2008-12                     90.5  47.6   93.4    87.8           95.9
# 4    2009-01                     87.6  48.7   85.2    80.6           93.2

# %%
Tot_M_IIP2.to_csv('Total Manufacturing IIPs Final_V.csv')

# %%
Financial_Crisis_TM = Tot_M_IIP2.iloc[0:17]
Financial_Crisis_TM.tail()
# Out:
#    Year-Month United States of America China  Japan Germany United Kingdom
# 12    2009-09                     87.6  54.2   92.6    84.5           93.6
# 13    2009-10                     87.7  55.1   94.9    82.7           93.6
# 14    2009-11                     88.6  55.6     97    83.4           94.9
# 15    2009-12                     88.5  56.4   97.8    83.5           94.8
# 16    2010-01                     89.5  56.8  100.3    84.3           94.3

# %%
COVID_TM = Tot_M_IIP2.iloc[17:]
COVID_TM.head()
# Out:
#    Year-Month United States of America  China Japan Germany United Kingdom
# 17    2020-03                     94.6  121.4  96.2    91.3           94.3
# 18    2020-04                     79.6    128  86.3    71.1           70.6
# 19    2020-05                     83.4  132.8  77.2    79.4           76.8
# 20    2020-06                     89.5  135.9    81    88.5           86.7
# 21    2020-07                     93.2  139.3  86.6    90.2           93.1

# %%
US_IIP_SAI2 = US_IIP_SAI
US_IIP_SAI2.index.names = ['']
US_IIP_SAI2 =US_IIP_SAI2.T
US_IIP_SAI2 = US_IIP_SAI2.reset_index()
US_IIP_SAI2['index'] = US_IIP_SAI2['index'].replace(r' M', '-', regex=True)
US_IIP_SAI2 = US_IIP_SAI2.rename(columns={'index':'Year-Month'})
US_IIP_SAI2
# Out:
#    Year-Month Food products  ... Furniture Other manufacturing
# 0     2008-09          95.6  ...     116.4               107.7
# 1     2008-10          96.9  ...     114.7               106.4
# 2     2008-11          96.8  ...     109.3               104.2
# 3     2008-12          94.8  ...     103.3               102.6
# 4     2009-01          94.9  ...      96.4               102.1
# 5     2009-02          95.7  ...      93.5                98.8
# 6     2009-03          95.1  ...      90.1                  98
# 7     2009-04          95.7  ...        89                98.3
# 8     2009-05          96.5  ...        87                97.7
# 9     2009-06          96.5  ...      85.8                97.2
# 10    2009-07          95.5  ...      85.8                97.7
# 11    2009-08          95.9  ...      84.8                99.8
# 12    2009-09          95.8  ...      84.8                99.9
# 13    2009-10          96.1  ...      84.6               100.1
# ...

# %%
US_IIP_SAI2['Year-Month'] = pd.to_datetime(US_IIP_SAI2['Year-Month'], format='%Y-%m').dt.strftime('%Y-%m')
US_IIP_SAI2.tail()
# Out:
#    Year-Month Food products  ... Furniture Other manufacturing
# 29    2021-03         105.1  ...      89.3                  97
# 30    2021-04         103.9  ...      88.7                96.1
# 31    2021-05           103  ...      90.9                96.9
# 32    2021-06         102.7  ...        91                97.2
# 33    2021-07           102  ...      91.2                  99
#
# [5 rows x 24 columns]

# %%
CN_IIP_SAI2 = CN_IIP_SAI
CN_IIP_SAI2.index.names = ['']
CN_IIP_SAI2 =CN_IIP_SAI2.T
CN_IIP_SAI2 = CN_IIP_SAI2.reset_index()
CN_IIP_SAI2['index'] = CN_IIP_SAI2['index'].replace(r' M', '-', regex=True)
CN_IIP_SAI2 = CN_IIP_SAI2.rename(columns={'index':'Year-Month'})
CN_IIP_SAI2['Year-Month'] = pd.to_datetime(CN_IIP_SAI2['Year-Month'], format='%Y-%m').dt.strftime('%Y-%m')
CN_IIP_SAI2
# Out:
#    Year-Month Food products  ... Furniture Other manufacturing
# 0     2008-09          47.4  ...      48.7                52.1
# 1     2008-10          48.3  ...      48.5                51.6
# 2     2008-11          48.4  ...      48.8                51.4
# 3     2008-12            50  ...      49.1                52.5
# 4     2009-01          50.6  ...      49.1                  52
# 5     2009-02          51.9  ...      49.9                53.2
# 6     2009-03          51.3  ...      49.9                52.2
# 7     2009-04          52.5  ...      49.9                52.2
# 8     2009-05            53  ...      49.9                52.4
# 9     2009-06            54  ...      51.4                52.6
# 10    2009-07          54.2  ...      51.2                53.2
# 11    2009-08          54.8  ...        52                53.5
# 12    2009-09          55.8  ...      53.2                54.1
# 13    2009-10          56.4  ...      54.6                54.7
# ...

# %%
JP_IIP_SAI2 = JP_IIP_SAI
JP_IIP_SAI2.index.names = ['']
JP_IIP_SAI2 =JP_IIP_SAI2.T
JP_IIP_SAI2 = JP_IIP_SAI2.reset_index()
JP_IIP_SAI2['index'] = JP_IIP_SAI2['index'].replace(r' M', '-', regex=True)
JP_IIP_SAI2 = JP_IIP_SAI2.rename(columns={'index':'Year-Month'})
JP_IIP_SAI2['Year-Month'] = pd.to_datetime(JP_IIP_SAI2['Year-Month'], format='%Y-%m').dt.strftime('%Y-%m')
JP_IIP_SAI2.head()
# Out:
#   Year-Month Food products  ... Furniture Other manufacturing
# 0    2008-09         102.3  ...     113.1               104.1
# 1    2008-10         104.8  ...     107.6                99.2
# 2    2008-11         105.9  ...     104.8               102.2
# 3    2008-12         104.6  ...      97.7                98.1
# 4    2009-01         104.1  ...     101.3                98.6
#
# [5 rows x 24 columns]

# %%
DE_IIP_SAI2 = DE_IIP_SAI
DE_IIP_SAI2.index.names = ['']
DE_IIP_SAI2 =DE_IIP_SAI2.T
DE_IIP_SAI2 = DE_IIP_SAI2.reset_index()
DE_IIP_SAI2['index'] = DE_IIP_SAI2['index'].replace(r' M', '-', regex=True)
DE_IIP_SAI2 = DE_IIP_SAI2.rename(columns={'index':'Year-Month'})
DE_IIP_SAI2['Year-Month'] = pd.to_datetime(DE_IIP_SAI2['Year-Month'], format='%Y-%m').dt.strftime('%Y-%m')
DE_IIP_SAI2
# Out:
#    Year-Month Food products  ... Furniture Other manufacturing
# 0     2008-09          97.5  ...     112.7                84.9
# 1     2008-10          97.6  ...     110.2                82.1
# 2     2008-11          96.2  ...     109.3                80.1
# 3     2008-12            99  ...     105.7                81.8
# 4     2009-01          98.9  ...     101.5                  82
# 5     2009-02          97.7  ...      97.1                78.4
# 6     2009-03          96.4  ...      97.8                75.3
# 7     2009-04          98.3  ...      98.4                76.6
# 8     2009-05          96.4  ...      98.2                  80
# 9     2009-06          97.2  ...      99.5                77.9
# 10    2009-07          97.5  ...      97.8                77.2
# 11    2009-08          97.2  ...      99.3                78.2
# 12    2009-09          99.1  ...      96.1                77.6
# 13    2009-10          96.5  ...      93.4                76.7
# ...

# %%
UK_IIP_SAI2 = UK_IIP_SAI
UK_IIP_SAI2.index.names = ['']
UK_IIP_SAI2 =UK_IIP_SAI2.T
UK_IIP_SAI2 = UK_IIP_SAI2.reset_index()
UK_IIP_SAI2['index'] = UK_IIP_SAI2['index'].replace(r' M', '-', regex=True)
UK_IIP_SAI2 = UK_IIP_SAI2.rename(columns={'index':'Year-Month'})
UK_IIP_SAI2['Year-Month'] = pd.to_datetime(UK_IIP_SAI2['Year-Month'], format='%Y-%m').dt.strftime('%Y-%m')
UK_IIP_SAI2
# Out:
#    Year-Month Food products  ... Furniture Other manufacturing
# 0     2008-09          92.4  ...     104.7                97.6
# 1     2008-10          93.4  ...      92.8               102.4
# 2     2008-11          91.4  ...      89.3                95.3
# 3     2008-12          90.8  ...      85.4                93.7
# 4     2009-01          92.2  ...      90.2                96.1
# 5     2009-02          92.1  ...      91.6                93.8
# 6     2009-03          92.1  ...      87.4                  99
# 7     2009-04          93.5  ...      90.4                94.1
# 8     2009-05          92.5  ...      96.2                96.9
# 9     2009-06          90.4  ...      86.2                95.7
# 10    2009-07          91.6  ...        87                94.3
# 11    2009-08          90.1  ...      88.7                97.4
# 12    2009-09          91.7  ...      91.2                98.6
# 13    2009-10          91.5  ...      90.3               101.3
# ...

# %% [markdown]
# # Sub-Task 2
# What are the changes in Total Manufacturing in five countries from March 2020 to July 2021?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(30,10))
plt.plot(COVID_TM['Year-Month'], COVID_TM['China'],c='firebrick')
plt.plot(COVID_TM['Year-Month'], COVID_TM['United States of America'],c='navy')
plt.plot(COVID_TM['Year-Month'], COVID_TM['Japan'],c='red')
plt.plot(COVID_TM['Year-Month'], COVID_TM['Germany'],c='slategrey')
plt.plot(COVID_TM['Year-Month'], COVID_TM['United Kingdom'],c='seagreen')
plt.legend(["China", "US", "Japan", "Germany", "UK"])
plt.xlabel("Year-Month")
plt.ylabel("Month-Over-Month Seasonally-Adjusted IIP of Total Manufacturing")
plt.title("Trends of Month-Over-Month Seasonally-Adjusted Index Industrial Production of Total Manufacturing: 17 Months After COVID-19 Was Declared by WHO as a Pandemic")
plt.savefig("M-O-M IIP Trends COVID.png")

# %% [markdown]
# # Sub-Task 3
# Between March 2020 and July 2021, which country experienced the greatest IIP growth of Total Manufacturing? Which country suffered from the worst IIP recession of Total Manufacturing?

# %%
plt.figure(figsize=(30,10))
plt.plot(COVID_TM['Year-Month'], (COVID_TM['China'].diff(1)/COVID_TM['China'].shift())*100,c='firebrick')
plt.plot(COVID_TM['Year-Month'], (COVID_TM['United States of America'].diff(1)/COVID_TM['United States of America'].shift())*100,c='navy')
plt.plot(COVID_TM['Year-Month'], (COVID_TM['Japan'].diff(1)/COVID_TM['Japan'].shift())*100,c='red')
plt.plot(COVID_TM['Year-Month'], (COVID_TM['Germany'].diff(1)/COVID_TM['Germany'].shift())*100,c='slategrey')
plt.plot(COVID_TM['Year-Month'], (COVID_TM['United Kingdom'].diff(1)/COVID_TM['United Kingdom'].shift())*100,c='seagreen')
plt.legend(["China", "US", "Japan", "Germany", "UK"])
plt.xlabel("Year-Month")
plt.ylabel("Percent Change of Month-Over-Month Seasonally-Adjusted IIP of Total Manufacturing (%)")
plt.title("Percent Change Trends of Month-Over-Month Seasonally-Adjusted Index Industrial Production of Total Manufacturing: 17 Months After COVID-19 Was Declared by WHO as a Pandemic")
plt.savefig("M-O-M IIP Percent Trends COVID.png")

# %% [markdown]
# # Sub-Task 4
# As of the latest month that data is available, what are the top three fastest growing manufacturing sectors (if five countries' growth of IIP are combined)?

# %%
plt.figure(figsize=(30,10))
plt.bar(July_2021['Industry_Sector'], July_2021['USA'], color='navy')
plt.bar(July_2021['Industry_Sector'], July_2021['China'], bottom=July_2021['USA'], color='firebrick')
plt.bar(July_2021['Industry_Sector'], July_2021['Japan'], bottom=July_2021['USA']+July_2021['China'], color='red')
plt.bar(July_2021['Industry_Sector'], July_2021['Germany'], bottom=July_2021['USA']+July_2021['China']+July_2021['Japan'], color='slategrey')
plt.bar(July_2021['Industry_Sector'], July_2021['UK'], bottom=July_2021['USA']+July_2021['China']+July_2021['Japan']+July_2021['Germany'], color='seagreen')
plt.xticks(rotation=75)
plt.legend(["US", "China", "Japan", "Germany", "UK"])
plt.xlabel("Industry Sectors")
plt.ylabel("Seasonally-Adjusted Index Industrial Production")
plt.title("Seasonally-Adjusted Index Industrial Production of Various Sectors, July 2021")
plt.savefig("IIP July 2021.png")

# %% [markdown]
# # Sub-Task 5
# For each country, what are the top three fastest growing manufacturing sectors in July 2021?

# %%
plt.figure(figsize=(30,10))
plt.bar(July_2021['Industry_Sector'], July_2021['USA'], color='navy')
plt.xticks(rotation=75)
plt.xlabel("Industry Sectors")
plt.ylabel("Seasonally-Adjusted Index Industrial Production")
plt.title("Seasonally-Adjusted Index Industrial Production of Various Sectors in U.S., July 2021")
plt.savefig("US IIP July 2021.png")

# %%
plt.figure(figsize=(30,10))
plt.bar(July_2021['Industry_Sector'], July_2021['China'], color='firebrick')
plt.xticks(rotation=75)
plt.xlabel("Industry Sectors")
plt.ylabel("Seasonally-Adjusted Index Industrial Production")
plt.title("Seasonally-Adjusted Index Industrial Production of Various Sectors in China, July 2021")
plt.savefig("China IIP July 2021.png")

# %%
plt.figure(figsize=(30,10))
plt.bar(July_2021['Industry_Sector'], July_2021['Japan'], color='red')
plt.xticks(rotation=75)
plt.xlabel("Industry Sectors")
plt.ylabel("Seasonally-Adjusted Index Industrial Production")
plt.title("Seasonally-Adjusted Index Industrial Production of Various Sectors in Japan, July 2021")
plt.savefig("Japan IIP July 2021.png")

# %%
plt.figure(figsize=(30,10))
plt.bar(July_2021['Industry_Sector'], July_2021['Germany'], color='slategrey')
plt.xticks(rotation=75)
plt.xlabel("Industry Sectors")
plt.ylabel("Seasonally-Adjusted Index Industrial Production")
plt.title("Seasonally-Adjusted Index Industrial Production of Various Sectors in Germany, July 2021")
plt.savefig("Germany IIP July 2021.png")

# %%
plt.figure(figsize=(30,10))
plt.bar(July_2021['Industry_Sector'], July_2021['UK'], color='seagreen')
plt.xticks(rotation=75)
plt.xlabel("Industry Sectors")
plt.ylabel("Seasonally-Adjusted Index Industrial Production")
plt.title("Seasonally-Adjusted Index Industrial Production of Various Sectors in U.K., July 2021")
plt.savefig("UK IIP July 2021.png")

# %% [markdown]
# # Sub-Task 6
# Which of the COVID-19 and the 2008-2009 Financial Crisis made a more significant impact on the manufacturing industries of five countries based on the changes of IPPs?

# %%
plt.figure(figsize=(30,10))
plt.scatter(Tot_M_IIP2['Year-Month'], Tot_M_IIP2['China'],c='firebrick')
plt.scatter(Tot_M_IIP2['Year-Month'], Tot_M_IIP2['United States of America'],c='navy')
plt.scatter(Tot_M_IIP2['Year-Month'], Tot_M_IIP2['Japan'],c='red')
plt.scatter(Tot_M_IIP2['Year-Month'], Tot_M_IIP2['Germany'],c='slategrey')
plt.scatter(Tot_M_IIP2['Year-Month'], Tot_M_IIP2['United Kingdom'],c='seagreen')
plt.legend(["China", "US", "Japan", "Germany", "UK"])
plt.xlabel("Year-Month")
plt.ylabel("Month-Over-Month Seasonally-Adjusted IIP of Total Manufacturing")
plt.title("Trends of Month-Over-Month Seasonally-Adjusted Index Industrial Production of Total Manufacturing, Separated by 2010-01 and 2020-03")
plt.savefig("M-O-M IIP Trends Combined.png")

# %%
plt.figure(figsize=(30,10))
plt.plot(Financial_Crisis_TM['Year-Month'], Financial_Crisis_TM['China'],c='firebrick')
plt.plot(Financial_Crisis_TM['Year-Month'], Financial_Crisis_TM['United States of America'],c='navy')
plt.plot(Financial_Crisis_TM['Year-Month'], Financial_Crisis_TM['Japan'],c='red')
plt.plot(Financial_Crisis_TM['Year-Month'], Financial_Crisis_TM['Germany'],c='slategrey')
plt.plot(Financial_Crisis_TM['Year-Month'], Financial_Crisis_TM['United Kingdom'],c='seagreen')
plt.legend(["China", "US", "Japan", "Germany", "UK"])
plt.xlabel("Year-Month")
plt.ylabel("Month-Over-Month Seasonally-Adjusted IIP of Total Manufacturing")
plt.title("Trends of Month-Over-Month Seasonally-Adjusted Index Industrial Production of Total Manufacturing: 17 Months After the Start of Global Financial Crisis")
plt.savefig("M-O-M IIP Trends Financial.png")

# %%
plt.figure(figsize=(30,10))
plt.plot(Financial_Crisis_TM['Year-Month'], (Financial_Crisis_TM['China'].diff(1)/Financial_Crisis_TM['China'].shift())*100,c='firebrick')
plt.plot(Financial_Crisis_TM['Year-Month'], (Financial_Crisis_TM['United States of America'].diff(1)/Financial_Crisis_TM['United States of America'].shift())*100,c='navy')
plt.plot(Financial_Crisis_TM['Year-Month'], (Financial_Crisis_TM['Japan'].diff(1)/Financial_Crisis_TM['Japan'].shift())*100,c='red')
plt.plot(Financial_Crisis_TM['Year-Month'], (Financial_Crisis_TM['Germany'].diff(1)/Financial_Crisis_TM['Germany'].shift())*100,c='slategrey')
plt.plot(Financial_Crisis_TM['Year-Month'], (Financial_Crisis_TM['United Kingdom'].diff(1)/Financial_Crisis_TM['United Kingdom'].shift())*100,c='seagreen')
plt.legend(["China", "US", "Japan", "Germany", "UK"])
plt.xlabel("Year-Month")
plt.ylabel("Percent Change of Month-Over-Month Seasonally-Adjusted IIP of Total Manufacturing (%)")
plt.title("Percent Change Trends of Month-Over-Month Seasonally-Adjusted Index Industrial Production of Total Manufacturing: 17 Months After the Start of Global Financial Crisis")
plt.savefig("M-O-M IIP Percent Trends Financial.png")
